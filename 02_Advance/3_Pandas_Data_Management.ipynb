# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset("lukebarousse/data_jobs")
df_original = dataset['train'].to_pandas()

# Data Cleanup
df_original["job_posted_date"] = pd.to_datetime(df_original["job_posted_date"])

# %%
df_original.sample(10, random_state = 31)
# Out:
#              job_title_short  \
# 2025           Data Engineer
# 445365        Data Scientist
# 751761          Data Analyst
# 53795         Data Scientist
# 555647        Data Scientist
# 743798          Data Analyst
# 202811     Software Engineer
# 265007   Senior Data Analyst
# 126009  Senior Data Engineer
# 320556          Data Analyst
#
#                                                 job_title  \
# 2025                                        Data Engineer
# 445365             Apply now as a Search Analyst - Remote
# 751761  Refugee Cash Assistance Data Analyst – Entry a...
# 53795                         Process Monitoring Engineer
# 555647                                     Data Scientist
# 743798                                       Data Analyst
# 202811                                  Software Engineer
# 265007           Senior System Analyst, Database Services
# 126009                               Senior Data Engineer
# ...

# %%
# Both Dataframe Referencing the same id that's why if one Dataframe is changed the second one is get changed automatically.
df_altered = df_original

# %%
print("df_original id is :", id(df_original))
print("df_altered id is :", id(df_altered))
print(id(df_original) == id(df_altered))
# Out:
# df_original id is : 2145087922448
# df_altered id is : 2145087922448
# True

# %%
df_altered.loc[:, "salary_rate" : "salary_hour_avg"]
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 0             None              NaN              NaN
# 1             None              NaN              NaN
# 2             None              NaN              NaN
# 3             None              NaN              NaN
# 4             None              NaN              NaN
# ...            ...              ...              ...
# 785736        None              NaN              NaN
# 785737        None              NaN              NaN
# 785738        None              NaN              NaN
# 785739        None              NaN              NaN
# 785740        None              NaN              NaN
#
# [785741 rows x 3 columns]

# %%
median_salary_year = df_altered["salary_year_avg"].median()
median_salary_hour = df_altered["salary_hour_avg"].median()

# %%
df_altered["salary_hour_avg"] = df_altered["salary_hour_avg"].fillna(median_salary_hour)
df_altered["salary_year_avg"] = df_altered["salary_year_avg"].fillna(median_salary_year)

# %%
df_altered.loc[:, "salary_rate" : "salary_hour_avg"]
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 0             None         115000.0            45.98
# 1             None         115000.0            45.98
# 2             None         115000.0            45.98
# 3             None         115000.0            45.98
# 4             None         115000.0            45.98
# ...            ...              ...              ...
# 785736        None         115000.0            45.98
# 785737        None         115000.0            45.98
# 785738        None         115000.0            45.98
# 785739        None         115000.0            45.98
# 785740        None         115000.0            45.98
#
# [785741 rows x 3 columns]

# %%
# I didn't changed the original Dataframe but it's referencing the df_altered DataFrame that's why it get changed automatically.
df_original.loc[:, "salary_rate" : "salary_hour_avg"]
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 0             None         115000.0            45.98
# 1             None         115000.0            45.98
# 2             None         115000.0            45.98
# 3             None         115000.0            45.98
# 4             None         115000.0            45.98
# ...            ...              ...              ...
# 785736        None         115000.0            45.98
# 785737        None         115000.0            45.98
# 785738        None         115000.0            45.98
# 785739        None         115000.0            45.98
# 785740        None         115000.0            45.98
#
# [785741 rows x 3 columns]

# %% [markdown]
# That's why we should use the Copy() method.

# %%
# Loading Data Again
dataset = load_dataset("lukebarousse/data_jobs")
df_original1 = dataset['train'].to_pandas()

# Data Cleanup
df_original1["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

# %%
df_altered1 = df_original1.copy()

# %%
print("df_original1 id is :", id(df_original1))
print("df_altered1 id is :", id(df_altered1))
print(id(df_original1) == id(df_altered1))
# Out:
# df_original1 id is : 2144760973264
# df_altered1 id is : 2144761580944
# False

# %%
df_altered1.loc[:, "salary_rate" : "salary_hour_avg"]
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 0             None              NaN              NaN
# 1             None              NaN              NaN
# 2             None              NaN              NaN
# 3             None              NaN              NaN
# 4             None              NaN              NaN
# ...            ...              ...              ...
# 785736        None              NaN              NaN
# 785737        None              NaN              NaN
# 785738        None              NaN              NaN
# 785739        None              NaN              NaN
# 785740        None              NaN              NaN
#
# [785741 rows x 3 columns]

# %%
median_salary_year = df_altered1["salary_year_avg"].median()
median_salary_hour = df_altered1["salary_hour_avg"].median()

# %%
df_altered1["salary_hour_avg"] = df_altered1["salary_hour_avg"].fillna(median_salary_hour)
df_altered1["salary_year_avg"] = df_altered1["salary_year_avg"].fillna(median_salary_year)

# %%
df_altered1.loc[:, "salary_rate" : "salary_hour_avg"]
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 0             None         115000.0            45.98
# 1             None         115000.0            45.98
# 2             None         115000.0            45.98
# 3             None         115000.0            45.98
# 4             None         115000.0            45.98
# ...            ...              ...              ...
# 785736        None         115000.0            45.98
# 785737        None         115000.0            45.98
# 785738        None         115000.0            45.98
# 785739        None         115000.0            45.98
# 785740        None         115000.0            45.98
#
# [785741 rows x 3 columns]

# %%
# This time the original DataFrame is not affected
df_original1.loc[:, "salary_rate" : "salary_hour_avg"]
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 0             None              NaN              NaN
# 1             None              NaN              NaN
# 2             None              NaN              NaN
# 3             None              NaN              NaN
# 4             None              NaN              NaN
# ...            ...              ...              ...
# 785736        None              NaN              NaN
# 785737        None              NaN              NaN
# 785738        None              NaN              NaN
# 785739        None              NaN              NaN
# 785740        None              NaN              NaN
#
# [785741 rows x 3 columns]
